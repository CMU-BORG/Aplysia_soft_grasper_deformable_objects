# %%
import pybullet as p
import pybullet_data
import pathlib
import pandas as pd
import numpy as np
import time
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from Gantry.envs.GantrySimulation import GantrySimulation
from Gantry.controller.SNS_layer import R, perceptor, perceptor_modulation, controller_closed_loop_v2, controller_modulation, controller_closed_loop_modulation, SNS_Control_closed_loop_v1, SNS_Control_closed_loop_v2, SNS_Control_closed_loop_modulation, pick_and_place
# Out:
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!
# alloc!

# %% [markdown]
# ## Some constant parameters used in simulation.
#
# object_position = [0, 0, -0.34] (m)
#
# target_position = [0.15, 0.15, -0.34] (m)
#
# mass = 1.0 kg (Here, we use a large weight to test the effect of time history dependent control)
#
# size scaling factor = 0.6
#
# simulation end time = 13 (sec)
#
# perceptor = perceptor (with an inhibitory synapse from the grasping-the-object command neuron to the lifting-the-object-up command neuron. This additional synapse can prevent the controller from transitioning to the lifting up phase too early)
#
# open-loop controller with time history dependent control = controller_modulation (jaws use position control)
#
# closed-loop controller with time history dependent control = controller_closed_loop_modulation (jaws use speed control to regulate force, time history dependent control regulates jaw pressure)
#
# force threshold gain = 0.1 (equivalent to multiplying force sensory signals by 10. Warning: this method may only work in simulation. Using a small gain in the experiment may lead to a force threshold lower than the noise level.)
#
# jaw pressure used in the open loop controller = 2.5 (PSI)
#
# grasper closing speed gain = 0.3
#
# time constants of neurons in the perceptor = 0.05 (sec)

# %%
OBJECT_POSITION = [0, 0, -0.34]
TARGET_POSITION = [0.15, 0.15, -0.34]
MASS = 1
SIZE_SCALING = 0.6

END_TIME = 50

PERCEPTOR = perceptor
OPEN_LOOP_CONTROLLER = controller_modulation
CLOSED_LOOP_CONTROLLER = controller_closed_loop_modulation
FORCE_THRESHOLD_GAIN = 0.1
PRESSURE_VALUE = 2.5
GRASPER_CLOSING_SPEED = 0.2
PERCEPTOR_TAU = 0.05

# %% [markdown]
# ## Some constant parameters used in plotting.
#
# xlim = (1, 11)
#
# limit for grasper command axis= (0, 0.1) (m)
#
# limit for contact force axis = (0, 50) (N)
#
# limit for pressure axis = (0, 3) (PSI)

# %%
XLIM = (1, END_TIME - 1)
GRASPER_COMMAND_LIM = (0, 0.1)
GRASPER_COMMAND_TICKS = np.arange(0, 0.12, step=0.05)
FORCE_LIM = (0, 50)
PRESSURE_COMMAND_LIM = (0, 3)
PRESSURE_COMMAND_TICKS = np.arange(0, 3, step=1)

# %% [markdown]
# ## Time history dependent control simulation
#
# We the test time history dependent control on an open loop controller and a closed loop controller (v2): Without neuromodulation, the open loop controller can only send a fixed jaw positIon during grasper closing phases. Time history dependent controLler can modulate the jaw position commands so that the grasper can generate higher contact forces if the first pick attempt fails. For the closed loop controller, time history dependent controLler modulates the jaw pressure commands.
#
# How to make the grasper fail on the first attempt: In the simulation, we use a quite heavy object (1 kg) to increase the difficulty of the task. The initial maximal jaw command of the open loop controller is set to a value lower than 0.1. This prevents the grasper from establishing strong contact with the object at the beginning. We also use a small force threshold so that the controller start picking the object up even with small contact forces. The low force threshold can be achieved by either setting a small force threshold gain for the perceptor, or using perceptor_modulation. perceptor_modulation is a special SNS that has no inhibitory synapses from the grasping-the-object command neuron to the lifting-the-object-up command neuron. Controller using this SNS tends to lift the object up earlier.

# %%
perceptor.set_tau(PERCEPTOR_TAU)
perceptor.reset()
controller_modulation.reset()
#controller_modulation._inter_layer_1._params["tau"].data[2]=2
neuron_history_open_loop_modulation, sensory_history_open_loop_modulation, command_history_open_loop_modulation = pick_and_place(position_o=OBJECT_POSITION, position_t=TARGET_POSITION, perceptor=PERCEPTOR, controller=OPEN_LOOP_CONTROLLER, PressureValue=PRESSURE_VALUE, end_time=END_TIME, force_threshold_gain=FORCE_THRESHOLD_GAIN, grasper_closing_speed = GRASPER_CLOSING_SPEED, zero_time_constant=False, mass=MASS, sizeScaling=SIZE_SCALING)

perceptor.set_tau(PERCEPTOR_TAU)
perceptor.reset()
controller_closed_loop_modulation.reset()
neuron_history_closed_loop_modulation, sensory_history_closed_loop_modulation, command_history_closed_loop_modulation = pick_and_place(position_o=OBJECT_POSITION, position_t=TARGET_POSITION, perceptor=PERCEPTOR, controller=CLOSED_LOOP_CONTROLLER, end_time=END_TIME, force_threshold_gain=FORCE_THRESHOLD_GAIN, grasper_closing_speed=GRASPER_CLOSING_SPEED, zero_time_constant=True, mass=MASS, sizeScaling=SIZE_SCALING)
# Out:
# Starting SNS!
#
# Changing time constant in SNS! Open loop modulation.
#
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[ 3.05739412e-12  3.62191112e-04 -9.86035633e+01]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[ 5.78116474e-13  2.64060720e-04 -7.18883660e+01]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-3.29513814e-14  2.60514187e-05 -7.09228540e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.93540172e-13  2.65320811e-05 -7.22314155e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.65334693e-13  2.68950378e-05 -7.32195376e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-7.25710962e-13  2.71104683e-05 -7.38060278e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-3.75914180e-14  2.71768094e-05 -7.39866373e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[ 7.27290077e-15  2.70952140e-05 -7.37645008e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.91949342e-13  2.68663724e-05 -7.31414982e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[ 3.09662978e-13  2.64915864e-05 -7.21211743e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[ 5.81202623e-14  2.59739204e-05 -7.07118700e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.16380518e-14  2.53188769e-05 -6.89285679e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-3.95626988e-13  2.45351267e-05 -6.67948719e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[ 9.05035248e-13  1.16733097e-04 -3.17796296e+01]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.16661206e-13  2.57216433e-05 -7.00250679e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.45588931e-13  3.04780435e-05 -8.29739759e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.81934758e-14  3.53088016e-05 -9.61253190e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.21146214e-13  3.53615892e-05 -9.62690292e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.86729953e-14  3.54108650e-05 -9.64031791e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.13487553e-13  3.54614216e-05 -9.65408151e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.45051838e-13  3.55082266e-05 -9.66682367e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.02985477e-13  3.55511679e-05 -9.67851418e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.74216430e-13  3.55905418e-05 -9.68923339e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.63951670e-13  3.56266507e-05 -9.69906385e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.35875322e-13  3.56597744e-05 -9.70808143e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.69229915e-13  3.56901661e-05 -9.71635529e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-4.29140343e-13  3.57180571e-05 -9.72394839e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.07604302e-13  3.57436583e-05 -9.73091813e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.52369508e-13  3.57671621e-05 -9.73731685e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.92483121e-13  3.57887441e-05 -9.74319234e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.68575866e-13  3.58085643e-05 -9.74858822e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-8.62020266e-14  3.58179805e-05 -9.75115172e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.78934474e-13  3.58521874e-05 -9.76046433e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.47271737e-14  3.58507060e-05 -9.76006094e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.77327873e-13  3.58731002e-05 -9.76615763e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-2.50848716e-13  3.58865125e-05 -9.76980902e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[-1.16702965e-13  3.58984227e-05 -9.77305142e+00]
# Doing work
# Doing work
# Programmatic Control
# BasePlateJoint:[
-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.629794540398
# Contact Stiffness: 1039.4818916635732
# Contact Stiffness: 1039.8623868935733
# SJ1:[5.14619418e-02 2.00230323e+01 4.22950651e-03]
# SJ2:[-15.71592199  -9.07354055   0.03649459]
# SJ3:[ 1.73158660e+01 -9.99726339e+00  1.09958422e-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.6297906296863
# Contact Stiffness: 1039.4819033323515
# Contact Stiffness: 1039.8624081611272
# SJ1:[5.14539530e-02 2.00230298e+01 4.20821797e-03]
# SJ2:[-15.71597164  -9.07356922   0.03649471]
# SJ3:[ 1.73158482e+01 -9.99725315e+00  1.10373516e-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.6297867189783
# Contact Stiffness: 1039.4819150007995
# Contact Stiffness: 1039.8624294287451
# SJ1:[5.14459638e-02 2.00230270e+01 4.18693064e-03]
# SJ2:[-15.7160213   -9.07359789   0.03649483]
# SJ3:[ 1.73158305e+01 -9.99724291e+00  1.10788615e-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.6297828084184
# Contact Stiffness: 1039.4819266693207
# Contact Stiffness: 1039.8624506969156
# SJ1:[5.14379753e-02 2.00230244e+01 4.16564548e-03]
# SJ2:[-15.71607095  -9.07362656   0.03649495]
# SJ3:[ 1.73158127e+01 -9.99723267e+00  1.11203707e-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.6297788979546
# Contact Stiffness: 1039.481938337695
# Contact Stiffness: 1039.8624719651011
# SJ1:[5.14299869e-02 2.00230217e+01 4.14436157e-03]
# SJ2:[-15.7161206   -9.07365522   0.03649507]
# SJ3:[ 1.73157950e+01 -9.99722243e+00  1.11618804e-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.6297749875116
# Contact Stiffness: 1039.4819500057376
# Contact Stiffness: 1039.862493233418
# SJ1:[5.14219982e-02 2.00230189e+01 4.12307934e-03]
# SJ2:[-15.71617024  -9.07368388   0.03649519]
# SJ3:[ 1.73157773e+01 -9.99721219e+00  1.12033900e-02]
# Doing work
# Doing work
# Programmatic Control
# Contact Stiffness: 1035.6297710772485
# Contact Stiffness: 1039.4819616738469
# Contact Stiffness: 1039.862514502154
# SJ1:[5.14140103e-02 2.00230163e+01 4.10179927e-03]
# SJ2:[-15.71621988  -9.07371254   0.03649531]
# SJ3:[ 1.73157595e+01 -9.99720195e+00  1.12448989e-02]
# Doing work
# Doing work
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 5
#       3 controller_modulation.reset()
#       4 #controller_modulation._inter_layer_1._params["tau"].data[2]=2
# ----> 5 neuron_history_open_loop_modulation, sensory_history_open_loop_modulation, command_history_open_loop_modulation = pick_and_place(position_o=OBJECT_POSITION, position_t=TARGET_POSITION, perceptor=PERCEPTOR, controller=OPEN_LOOP_CONTROLLER, PressureValue=PRESSURE_VALUE, end_time=END_TIME, force_threshold_gain=FORCE_THRESHOLD_GAIN, grasper_closing_speed = GRASPER_CLOSING_SPEED, zero_time_constant=False, mass=MASS, sizeScaling=SIZE_SCALING)
#       7 perceptor.set_tau(PERCEPTOR_TAU)
#       8 perceptor.reset()
#
# File V:\Research\FRR\FRR Soft Grasper\FRR_SoftGrasper\PyBullet Model\Gantry\controller\SNS_layer.py:696, in pick_and_place(position_o, position_t, perceptor, controller, PressureValue, end_time, force_threshold_gain, inhibitory_gain, grasper_closing_speed, zero_time_constant, mass, sizeScaling)
#     693 ArgumentDict = {"x_gantryHead": x_d, "y_BasePos": y_d, "z_AxisBar": z_d, "x_force": 50, "y_force": 500, "z_force": 500, "GrasperArguments": GrasperArguments}
#     695 # ---------step the simulation----------
# --> 696 gS.stepSim(usePositionControl=True, GUI_override=True, **ArgumentDict)  # pass argument dict to function
#     697 if ts * nsteps > end_time:
#     698     gS.bulletClient.disconnect()
#
# File V:\Research\FRR\FRR Soft Grasper\FRR_SoftGrasper\PyBullet Model\Gantry\envs\GantrySimulation.py:409, in GantrySimulation.stepSim(self, usePositionControl, logForcesAndTorques, GUI_override, x_gantryHead, y_BasePos, z_AxisBar, x_force, y_force, z_force, maxVelocity_x, maxVelocity_y, maxVelocity_z, GrasperArguments)
#     406 ZAxisBarIndex = self.GantryLinkIndex_dict["ZAxisBarIndex"]
#     407 GantryHeadIndex = self.GantryLinkIndex_dict["GantryHeadIndex"]
# --> 409 BasePosTarget = self.bulletClient.readUserDebugParameter(self.GUIcontrols["BasePositionId"])
#     410 ZAxisBarTarget = self.bulletClient.readUserDebugParameter(self.GUIcontrols["ZAxisBarId"])
#     411 GantryHeadTarget = self.bulletClient.readUserDebugParameter(self.GUIcontrols["GantryHeadDebugId"])
#
# error: Not connected to physics server.

# %% [markdown]
# ## Plot the time history of the contact forces, Jaw commands, and pressure commands in the above simulations.

# %%
def time_history_dependent_control_plot(neuron_history_open_loop_modulation, sensory_history_open_loop_modulation, command_history_open_loop_modulation, neuron_history_closed_loop_modulation, sensory_history_closed_loop_modulation, command_history_closed_loop_modulation, xlim=XLIM, grasper_command_lim=GRASPER_COMMAND_LIM, pressure_command_lim=PRESSURE_COMMAND_LIM, force_lim=FORCE_LIM, grasper_command_ticks=GRASPER_COMMAND_TICKS, pressure_command_ticks=PRESSURE_COMMAND_TICKS):
    plt.rcParams['axes.spines.top'] = False
    plt.rcParams['axes.spines.right'] = False

    fig, ax = plt.subplots(3)
    time_history = np.arange(neuron_history_open_loop_modulation[:, 0].size) / 240
    
    ax[0].plot(time_history, command_history_open_loop_modulation[:, 3])
    ax[0].plot(time_history, command_history_closed_loop_modulation[:, 3])
    ax[0].set_ylabel('Radius')
    ax[0].set(ylim=grasper_command_lim, xlim=xlim)
    ax[0].spines['bottom'].set_visible(False)
    ax[0].axes.get_xaxis().set_visible(False)
    ax[0].axes.set_yticks(grasper_command_ticks)

    ax[1].plot(time_history, command_history_open_loop_modulation[:, 4])
    ax[1].plot(time_history, command_history_closed_loop_modulation[:, 4])
    ax[1].set_ylabel('Pressure')
    ax[1].set(ylim=pressure_command_lim, xlim=xlim)
    ax[1].spines['bottom'].set_visible(False)
    ax[1].axes.get_xaxis().set_visible(False)
    ax[1].axes.set_yticks(pressure_command_ticks)

    ax[2].plot(time_history, np.sum(sensory_history_open_loop_modulation[:, 3:5], axis=1), label='Open loop')
    ax[2].plot(time_history, np.sum(sensory_history_closed_loop_modulation[:, 3:5], axis=1), label='Closed loop')
    ax[2].set_xlabel('Time')
    ax[2].set_ylabel('Contact Force')
    ax[2].set(ylim=force_lim, xlim=xlim)
    ax[2].legend(frameon=False)

    plt.show()
    return

time_history_dependent_control_plot(neuron_history_open_loop_modulation, sensory_history_open_loop_modulation, command_history_open_loop_modulation, neuron_history_closed_loop_modulation, sensory_history_closed_loop_modulation, command_history_closed_loop_modulation)
